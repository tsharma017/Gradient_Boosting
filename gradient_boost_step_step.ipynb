# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
X =np.random.rand(100,1)-0.5
y = 3*X[:,0]**2 + 0.5 * np.random.randn(100)
print(X)
print(y)
# Out:
# [[-0.12545988]
#  [ 0.45071431]
#  [ 0.23199394]
#  [ 0.09865848]
#  [-0.34398136]
#  [-0.34400548]
#  [-0.44191639]
#  [ 0.36617615]
#  [ 0.10111501]
#  [ 0.20807258]
#  [-0.47941551]
#  [ 0.46990985]
#  [ 0.33244264]
#  [-0.28766089]
#  [-0.31817503]
#  [-0.31659549]
#  [-0.19575776]
#  [ 0.02475643]
#  [-0.06805498]
#  [-0.20877086]
#  [ 0.11185289]
#  [-0.36050614]
#  [-0.20785535]
#  [-0.13363816]
#  [-0.04393002]
#  [ 0.28517596]
#  [-0.30032622]
#  [ 0.01423444]
#  [ 0.09241457]
#  [-0.45354959]
#  [ 0.10754485]
#  [-0.32947588]
#  [-0.43494841]
#  [ 0.44888554]
#  [ 0.46563203]
#  [ 0.30839735]
#  [-0.19538623]
#  [-0.40232789]
#  [ 0.18423303]
#  [-0.05984751]
#  [-0.37796177]
#  [-0.00482309]
#  [-0.46561148]
#  [ 0.4093204 ]
#  [-0.24122002]
#  [ 0.16252228]
#  [-0.18828892]
#  [ 0.02006802]
#  [ 0.04671028]
#  [-0.31514554]
#  [ 0.46958463]
#  [ 0.27513282]
#  [ 0.43949894]
#  [ 0.39482735]
#  [ 0.09789998]
#  [ 0.42187424]
#  [-0.4115075 ]
#  [-0.30401714]
#  [-0.45477271]
#  [-0.17466967]
#  [-0.11132271]
#  [-0.22865097]
#  [ 0.32873751]
#  [-0.14324667]
#  [-0.21906549]
#  [ 0.04269608]
#  [-0.35907578]
#  [ 0.30219698]
#  [-0.42544936]
#  [ 0.48688694]
#  [ 0.27224477]
#  [-0.30128432]
#  [-0.49447788]
#  [ 0.31546143]
#  [ 0.20685734]
#  [ 0.22900717]
#  [ 0.27127035]
#  [-0.42595535]
#  [-0.14153427]
#  [-0.38413094]
#  [ 0.36310343]
#  [ 0.12329813]
#  [-0.16910198]
#  [-0.43644165]
#  [-0.18901768]
#  [-0.17481668]
#  [ 0.22960618]
#  [ 0.13755747]
#  [ 0.38721274]
#  [-0.02778507]
#  [-0.38040575]
#  [ 0.21324479]
#  [ 0.26078505]
#  [ 0.0612772 ]
#  [ 0.27096718]
#  [-0.0062044 ]
#  [ 0.02273283]
#  [-0.07245898]
#  [-0.47458087]
#  [-0.39210857]]
# [ 0.09074408  0.45992648  0.20734396 -0.96458397  0.24513358  0.5335756
#   1.3248173   0.1431198  -0.37357406 -0.12099593  1.14721874  0.82682136
#   0.06667423  0.50488008  0.35224483  0.78502061 -0.23606325 -0.16199243
#  -0.18215964 -0.60100166  0.18559335  0.52042167  0.13216827 -0.0637161
#  -0.70189583  0.03365333  0.09923025 -0.40053078 -0.0550215   0.81914711
#   0.97779064  0.41295197  0.69631555  0.56727172 -0.30894604  0.27206984
#   0.14464244  1.71722424  0.00564494  0.16151884  0.4112094  -0.58426923
#   1.22179356  0.87859609  0.57007727 -0.37545325  0.80775531 -0.69971735
#   0.2999741   1.39317796  0.16626101 -0.05605465  0.62930364  0.21592808
#  -0.7465785   0.5682151  -0.02313659  0.51407548  0.16074254  0.86649568
#  -0.35444841 -0.00418696  0.73096366 -0.55387333  0.25769903  0.65904024
#  -0.41693538  0.36628597  0.67296286  1.1020881  -0.39612371 -0.38791158
#   0.99449591  0.44704008  0.25361631  0.33055695 -0.11924956  0.66044072
#   0.20663209  0.08549403  1.32841955  0.28252374 -0.50986531  0.89972075
#  -0.38015779  0.48522491  0.73745478 -0.35357499  0.93148919  0.20870649
#   0.84515569  1.08481651  0.08133247 -0.3656034  -0.22448758 -0.40778966
#  -0.03700051  0.1863269   0.81402642  0.87483902]

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['X'] = X.reshape(100)
df['y'] = y
df
# Out:
#            X         y
# 0  -0.125460  0.090744
# 1   0.450714  0.459926
# 2   0.231994  0.207344
# 3   0.098658 -0.964584
# 4  -0.343981  0.245134
# ..       ...       ...
# 95 -0.006204 -0.407790
# 96  0.022733 -0.037001
# 97 -0.072459  0.186327
# 98 -0.474581  0.814026
# 99 -0.392109  0.874839
#
# [100 rows x 2 columns]

# %%
plt.scatter(df['X'],df['y'])
plt.title('X vs y')
# Out:
# Text(0.5, 1.0, 'X vs y')

# %%
df['pred1'] = df['y'].mean()
df
# Out:
#            X         y     pred1
# 0  -0.125460  0.090744  0.264972
# 1   0.450714  0.459926  0.264972
# 2   0.231994  0.207344  0.264972
# 3   0.098658 -0.964584  0.264972
# 4  -0.343981  0.245134  0.264972
# ..       ...       ...       ...
# 95 -0.006204 -0.407790  0.264972
# 96  0.022733 -0.037001  0.264972
# 97 -0.072459  0.186327  0.264972
# 98 -0.474581  0.814026  0.264972
# 99 -0.392109  0.874839  0.264972
#
# [100 rows x 3 columns]

# %%
df['res1'] = df['y']-df['pred1']
df
# Out:
#            X         y     pred1      res1
# 0  -0.125460  0.090744  0.264972 -0.174228
# 1   0.450714  0.459926  0.264972  0.194954
# 2   0.231994  0.207344  0.264972 -0.057628
# 3   0.098658 -0.964584  0.264972 -1.229556
# 4  -0.343981  0.245134  0.264972 -0.019839
# ..       ...       ...       ...       ...
# 95 -0.006204 -0.407790  0.264972 -0.672762
# 96  0.022733 -0.037001  0.264972 -0.301973
# 97 -0.072459  0.186327  0.264972 -0.078645
# 98 -0.474581  0.814026  0.264972  0.549054
# 99 -0.392109  0.874839  0.264972  0.609867
#
# [100 rows x 4 columns]

# %%
plt.scatter(df['X'],df['y'])
plt.plot(df['X'],df['pred1'],color = 'red')

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree1 = DecisionTreeRegressor(max_leaf_nodes = 8)

# %%
tree1.fit(df['X'].values.reshape(100,1),df['res1'].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
from sklearn.tree import plot_tree
plot_tree(tree1)
plt.show()

# %%
X_test = np.linspace(-0.5,0.5,500)
print(X_test)
y_pred = 0.2654 + tree1.predict(X_test.reshape(500,1))
# Out:
# [-0.5        -0.49799599 -0.49599198 -0.49398798 -0.49198397 -0.48997996
#  -0.48797595 -0.48597194 -0.48396794 -0.48196393 -0.47995992 -0.47795591
#  -0.4759519  -0.4739479  -0.47194389 -0.46993988 -0.46793587 -0.46593186
#  -0.46392786 -0.46192385 -0.45991984 -0.45791583 -0.45591182 -0.45390782
#  -0.45190381 -0.4498998  -0.44789579 -0.44589178 -0.44388778 -0.44188377
plt.plot(X_test,y_pred,linewidth=2,color='red')
plt.scatter(df['X'],df['y'])

# %%
df['pred2'] = 0.2654 + tree1.predict(df['X'].values.reshape(100,1))
df
# Out:
#            X         y     pred1      res1     pred2
# 0  -0.125460  0.090744  0.264972 -0.174228 -0.222475
# 1   0.450714  0.459926  0.264972  0.194954  0.522179
# 2   0.231994  0.207344  0.264972 -0.057628  0.141227
# 3   0.098658 -0.964584  0.264972 -1.229556 -0.222475
# 4  -0.343981  0.245134  0.264972 -0.019839  0.332567
# ..       ...       ...       ...       ...       ...
# 95 -0.006204 -0.407790  0.264972 -0.672762 -0.222475
# 96  0.022733 -0.037001  0.264972 -0.301973 -0.222475
# 97 -0.072459  0.186327  0.264972 -0.078645 -0.222475
# 98 -0.474581  0.814026  0.264972  0.549054  0.856185
# 99 -0.392109  0.874839  0.264972  0.609867  0.856185
#
# [100 rows x 5 columns]

# %%
df['res2'] = df['y']-df['pred2']
df
# Out:
#            X         y     pred1      res1     pred2      res2
# 0  -0.125460  0.090744  0.264972 -0.174228 -0.222475  0.313220
# 1   0.450714  0.459926  0.264972  0.194954  0.522179 -0.062253
# 2   0.231994  0.207344  0.264972 -0.057628  0.141227  0.066117
# 3   0.098658 -0.964584  0.264972 -1.229556 -0.222475 -0.742109
# 4  -0.343981  0.245134  0.264972 -0.019839  0.332567 -0.087433
# ..       ...       ...       ...       ...       ...       ...
# 95 -0.006204 -0.407790  0.264972 -0.672762 -0.222475 -0.185314
# 96  0.022733 -0.037001  0.264972 -0.301973 -0.222475  0.185475
# 97 -0.072459  0.186327  0.264972 -0.078645 -0.222475  0.408802
# 98 -0.474581  0.814026  0.264972  0.549054  0.856185 -0.042159
# 99 -0.392109  0.874839  0.264972  0.609867  0.856185  0.018654
#
# [100 rows x 6 columns]

# %%
tree2 = DecisionTreeRegressor(max_leaf_nodes = 8)
tree2.fit(df['X'].values.reshape(100,1),df['res2'].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
y_pred = 0.2654 + sum(regressor.predict(X_test.reshape(-1,1)) for regressor in [tree1, tree2])

# %%
plt.figure(figsize = (14,4))
plt.subplot(121)
plt.plot(X_test,y_pred, linewidth = 2, color = 'red')
plt.scatter(df['X'],df['y'])
plt.title(['X vs y'])
# Out:
# Text(0.5, 1.0, "['X vs y']")

# %%
def gradient_boost(X,y,number,lr,count=1,regs=[],foo=None):
    if number ==0:
        return
    else:
        # do gradient boosting

        if count > 1:
            y = y - regs[-1].predict(X)
        else:
            foo = y

        tree_reg = DecisionTreeRegressor(max_depth=5, random_state=42)
        tree_reg.fit(X,y)

        regs.append(tree_reg)

        x1 = np.linspace(-0.5, 0.5, 500)
        y_pred = sum(lr * regressor.predict(x1.reshape(-1,1)) for regressor in regs)

        print(number)
        plt.figure()
        plt.plot(x1,y_pred, linewidth = 2)
        plt.plot(X[:,0], foo, "r.")
        plt.show()

        gradient_boost(X,y,number-1,lr,count+1, regs, foo=foo)

# %%
np.random.seed(42)
X=np.random.rand(100,1) - 0.5
y = 3*X[:,0]**2 + 0.05 * np.random.randn(100)
gradient_boost(X,y,5,lr=1)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
np.sqrt(np.dot(b-a,b-a))
# Out:
# 1.0
